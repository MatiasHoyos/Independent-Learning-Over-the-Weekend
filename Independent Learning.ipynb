# %%
# import pandas with shortcut 'pd'
import pandas as pd

# read the csv file which contains the data
data = pd.read_csv('constituents-financials.csv')



# drop function which is used in removing or deleting columns form the file. this is edited ny omitting the column that I want to see displayed
data.drop('Sector', inplace=True, axis=1) # the "True" is used in order to replace or in this scenario delte the column
data.drop('Price', inplace=True, axis=1)
data.drop('Dividend Yield', inplace=True, axis=1)
data.drop('52 Week Low', inplace=True, axis=1)
data.drop('52 Week High', inplace=True, axis=1)
data.drop('Market Cap', inplace=True, axis=1)
data.drop('EBITDA', inplace=True, axis=1)
data.drop('Price/Sales', inplace=True, axis=1)
data.drop('SEC Filings', inplace=True, axis=1)
data.drop('Earnings/Share', inplace=True, axis=1)
data.drop('Price/Earnings', inplace=True, axis=1)  


# display
print("\nCSV Data after deleting some columnsfrom lowest to highest :\n")



data.sort_values(["Price/Book"], # this is the sorting program which helps order from smallest to highest
					axis=0,
					ascending=[True],
					inplace=True)


# displays the column that I choose and also sorted from smallest to highest
print("\nAfter sorting:")
print(data)  


data1 = pd.read_csv('constituents-financials.csv')



# smae program as the first one but a new "data" variable in order to obtsin the data from a different column.
data1.drop('Sector', inplace=True, axis=1)
data1.drop('Price', inplace=True, axis=1)
data1.drop('Dividend Yield', inplace=True, axis=1)
data1.drop('52 Week Low', inplace=True, axis=1)
data1.drop('52 Week High', inplace=True, axis=1)
data1.drop('Market Cap', inplace=True, axis=1)
data1.drop('EBITDA', inplace=True, axis=1)
data1.drop('Price/Sales', inplace=True, axis=1)
data1.drop('SEC Filings', inplace=True, axis=1)
data1.drop('Earnings/Share', inplace=True, axis=1)
data1.drop('Price/Book', inplace=True, axis=1)



print("\nCSV Data after deleting some columns from lowest to highest :\n")



data1.sort_values(["Price/Earnings"],
					axis=0,
					ascending=[True],
					inplace=True)



print("\nAfter sorting:")
print(data1)

data2 = pd.read_csv('constituents-financials.csv')





data2.drop('Sector', inplace=True, axis=1)
data2.drop('Price', inplace=True, axis=1)
data2.drop('Dividend Yield', inplace=True, axis=1)
data2.drop('52 Week Low', inplace=True, axis=1)
data2.drop('52 Week High', inplace=True, axis=1)
data2.drop('Market Cap', inplace=True, axis=1)
data2.drop('Price/Earnings', inplace=True, axis=1)
data2.drop('Price/Sales', inplace=True, axis=1)
data2.drop('SEC Filings', inplace=True, axis=1)
data2.drop('Earnings/Share', inplace=True, axis=1)
data2.drop('Price/Book', inplace=True, axis=1)



print("\nCSV Data after deleting some columns from lowest to highest :\n")



data2.sort_values(["EBITDA"],
					axis=0,
					ascending=[True],
					inplace=True)



print("\nAfter sorting:")
print(data2)



import pandas as pd
import matplotlib
import math
file = "constituents-financials.csv"
df = pd.read_csv(file)



chambMean = df.groupby("Sector")[["Dividend Yield"]].mean()
print("\nTHIS IS THE MEAN", chambMean)

chambMean.plot(kind = "bar", title = "Mean Dividend Yield per Sector", ylabel = "Mean Dividend Yield", xlabel = "Sector")

partMedian = df.groupby("Sector")[["Dividend Yield"]].median()
print("\nTHIS IS THE MEDIAN", partMedian)
# Out:
# CSV Data after deleting some columnsfrom lowest to highest :
#
#
# After sorting:
#     Symbol                                Name  Price/Book
# 79     BHF           Brighthouse Financial Inc        0.51
# 386    RRC               Range Resources Corp.        0.59
# 170   EVHC                 Envision Healthcare        0.64
# 237    HPQ                             HP Inc.        0.66
# 35     AIG  American International Group, Inc.        0.75
# ..     ...                                 ...         ...
# 292    MRO                  Marathon Oil Corp.         NaN
# 346    OXY                Occidental Petroleum         NaN
# 358    PEP                        PepsiCo Inc.         NaN
# 450    TDG                     TransDigm Group         NaN
# 460    UNP                       Union Pacific         NaN
#
# [505 rows x 3 columns]
#
# CSV Data after deleting some columns from lowest to highest :
#
#
# After sorting:
#     Symbol                         Name  Price/Earnings
# ...
